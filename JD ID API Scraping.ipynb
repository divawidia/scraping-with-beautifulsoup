# %%
import requests
import pandas as pd

# %%
url = 'https://color.jd.id/shop_decoration_ina/search/2.0'

query_params = {
    'pageSize':'50',
    'mergeSku':'true', 
    'venderId':'10025373',
    'pageNo':'1',
    'orderBy':'1',
    'catLevel':'-1',
    'filters':'{}',
    '_token':'4894b5cf85d4da7553de6224bd57426d'
}

headers = {
    'authority': 'color.jd.id',
    'accept': '*/*',
    'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry=%7B%22id%22%3A%2262%22%7D; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _gid=GA1.2.585924019.1668600691; __jd_ab=1; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI%20Jakarta|10100004:Kota%20Jakarta%20Selatan|10100033:Setia%20Budi|10100209:Karet%20Kuningan; moe_uuid=ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a; USER_DATA=%7B%22attributes%22%3A%5B%5D%2C%22subscribedToOldSdk%22%3Afalse%2C%22deviceUuid%22%3A%22ea3dfb1c-f3b2-4cf7-bf83-a9b39eac502a%22%2C%22deviceAdded%22%3Atrue%7D; shshshfpa=a7fce101-466d-8ca7-109c-9b3d3a896bc0-1668672773; site=undefined; shshshfpb=iyCjL7701bdt0nv0hai9Xjg; x_api_device_token=38e0fb2e-3091-4227-883f-a1f9a0dc17e3; _tk=U1gi2ai652gcqmvseh31klo7sq0; _gia_s_local_fingerprint=6465bf402a49e4ecc47d679c1b8c8438; _gia_s_e_joint={"eid":"FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU","ma":"","im":"","os":"Android 6.x","ip":"182.253.132.113","ia":"","uu":"","at":"6"}; TrackID=1thqAgyJR7lnAMleDW1k0d4xCVQr13iO1iaLtj9v3CmOgkTquX4CkYwNmLZmvMubaoFq_yg7TzPOm2Ck_bN3s3Q; pinId=2l-AJG5YkWyr6ERWVo1rrbKS7MJkIcs6; pin=jdid_deglekwqxwlc; unick=jdid_eqtGCmjycoit; me=05429cefa54876c1fac907b8fde611ef; jmp=5b1dbe1e2e8d757935d0ef70227f6cc1e9e5294b5fef3506fd199b439ac6992f; _tp=""; logining=1; _pst=jdid_deglekwqxwlc; __jdv=63461492|accounts.google.com|-|organic|notset|1668674909535; regional_pin=jdid_deglekwqxwlc; shshshfp=33319963642e045354a388aec577adcd; 3AB9D23F7A4B3C9B=FK2TYVRWIWHAB363FQW42A3QEJI4YCS3VSHNIR5IH6ZE7WLUAXZSH2ALRJOCGX64HCHW5X2OESC2VIW6WGNMRI43ZU; _browser_id=1668675465314; language=en_US; _searchHistory=set%2520top%2520box%2CAdvan%2Csanken%2Caerostreet%2Cnike; __jda=63461492.166860068555036447537.1668600685.1668674910.1668677935.6; __jdb=63461492.1.166860068555036447537|6.1668677935; __jdc=63461492; lighting-id=...; _ga_VZMC86167F=GS1.1.1668677723.5.1.1668677936.57.0.0; _ga=GA1.2.221065702.1668600688; _dc_gtm_UA-69994851-1=1; cto_bundle=hSKKD19FN29CQUJ3eHRQJTJCUEUlMkZFb0hzR0R6UGJuWjFsWmVBa204dmdtUFNicFJBSmREUHA4V2xLMEtxd2ZTQlElMkJRTFklMkZNWG5SSW9ZQnRZZDN5V1NTazBrNEJMdEVLZzJZeDNxNWFLbUZNaGJCNkJPS1BxRGEwRXhSZ0FuQzBJY2lSVFRj; RT="z=1&dm=jd.id&si=tzffp8d6mx&ss=laktxsob&sl=m&tt=1ahz&ld=1tl1n&nu=a3a1554806bcd827b35adfaedd49f767&cl=1unh3"',
    'lang': 'id',
    'origin': 'https://www.jd.id',
    'referer': 'https://www.jd.id/',
    'sec-ch-ua': '"Microsoft Edge";v="107", "Chromium";v="107", "Not=A?Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
    'x-api-timestamp': '1668679359139'
}

result_product = []

data = requests.request("POST", url, headers=headers, params=query_params).json()

for i in range(1, data['data']['pageCount']+1):
    query_params_productlist = {
        'pageSize':'50',
        'mergeSku':'true', 
        'venderId':'10025373',
        'pageNo':f'{i}',
        'orderBy':'1',
        'catLevel':'-1',
        'filters':'{}',
        '_token':'4894b5cf85d4da7553de6224bd57426d'
    }

    productlist = requests.request("POST", url, headers=headers, params=query_params_productlist).json()
    for product in productlist['data']['skuList']:
        result_product.append(product)

# %%
result_product[0]['skuId']
# Out:
# 625499074

# %%
df = pd.json_normalize(result_product)
df
# Out:
#       commentNum goodComment  \
# 0             75           5
# 1             35           5
# 2             10           5
# 3              6           5
# 4             33           5
# ...          ...         ...
# 1118           0         5.0
# 1119           0         5.0
# 1120           0         5.0
# 1121           0         5.0
# 1122           0         5.0
#
#                                                imageUrl  promoStatus  \
# 0     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...            0
# 1     https://img12.jd.id/zhipu/amZzL3Q5Ny8yNy8xMTEy...            0
# 2     https://img12.jd.id/zhipu/amZzL3Q5Ny8yMDgvNjI2...            0
# 3     https://img12.jd.id/zhipu/amZzL3QxMDAvMTE1Lzc1...            0
# 4     https://img12.jd.id/zhipu/amZzL3Q4OC84Ni83MDgx...            0
# ...                                                 ...          ...
# 1118  https://img12.jd.id/zhipu/amZzL3QzNC8xNy81NDEw...            0
# ...

# %%
url_review = 'https://color.jd.id/jdid_pc_website/comment_product_page/1.0'

data_product = []
for index in range(0, len(result_product)):
    product_review = []

    query_params_review = {
        'spuId':f'{result_product[index]["spuId"]}',
        'skuId':f'{result_product[index]["skuId"]}',
        'storeId':'',
        'pageSize':'50',
        'pageIndex':'1',
        'tagId':'',
        'commentType':''
    }

    headers_review = {
        'authority': 'color.jd.id',
        'accept': '*/*',
        'cookie': 'mba_muid=166860068555036447537; _deviceId=cbeb6b66-d448-4b21-aab0-611c512b955d; eptCountry=%7B%22id%22%3A%2262%22%7D; _gcl_au=1.1.799070587.1668600687; GarudaShop=Other Page; _gid=GA1.2.585924019.1668600691; __jd_ab=1; _fbp=fb.1.1668600717483.1200734578; address_flag=true; stateId=10100000; cityId=10100004; areaId=10100033; townId=10100209; regional_full=10100000:DKI%20Jakarta|10100004:Kota%20Jakarta%20Selatan|10100033:Setia%20

        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42',
        'x-api-platform': 'PC',
        'x-api-timestamp': '1668680185752'
    }

    response_review = requests.request("POST", url_review, headers=headers_review, params=query_params_review).json()

    for page in range(1, round(response_review['data']['total']/50)+2):
        query_params_review = {
            'spuId':f'{result_product[index]["spuId"]}',
            'skuId':f'{result_product[index]["skuId"]}',
            'storeId':'',
            'pageSize':'50',
            'pageIndex':f'{page}',
            'tagId':'',
            'commentType':''
        }

        response_reviews = requests.request("POST", url_review, headers=headers_review, params=query_params_review).json()
        for review in response_reviews['data']['items']:
            product_review.append(review)

    product = result_product[index]
    product.update({"review_detail" : product_review})
    data_product.append(product)

# %%
data_product[0]['commentChildrens']
# Out:
# [{'commentId': '548368176',
#   'commentDate': 1662802514000,
#   'content': 'sepatunya keren, mengganti sepatu anak yg udah rusak, terbaik kualitasnya👍',
#   'imgList': ['amZzL3Q5Ny8yNTgvMTU3Mjg3MDg2MDYvOTc1Mzg1L2UwNDI4ZjdjLzYzMWM1YTE4TjQ2ZjQ3YTQ3.png',
#    'amZzL3QxMDkvMTAvMzI1NzE1MjM1LzgzNjg4OC83ODBjNDNlLzYzMWM1YTE3TmExNjEwNjE5.png',
#    'amZzL3QxMjEvMjcxLzI2MzYwNDI3NC84MTM2OTMvMWYwYmYyNzUvNjMxYzVhMTdOY2E5NzQ3ZGI.png'],
#   'state': 'AUDIT_PASSED',
#   'replyYn': 0,
#   'ip': '112.215.235.64',
#   'commentAgain': 0,
#   'commentType': 5,
#   'venderReply': 0,
#   'replyVO': None,
#   'manCommentStatus': 'NORMAL',
#   'spuId': 625499071,
#   'commentTagVOList': [],
#   'orderId': 1110928465,
#   'imgPropList': [1, 1, 1],
#   'videoList': []}]

# %%
df_review = pd.json_normalize(data_product)
df_review
# Out:
#       commentNum goodComment  \
# 0             75           5
# 1             35           5
# 2             10           5
# 3              6           5
# 4             33           5
# ...          ...         ...
# 1118           0         5.0
# 1119           0         5.0
# 1120           0         5.0
# 1121           0         5.0
# 1122           0         5.0
#
#                                                imageUrl  promoStatus  \
# 0     https://img12.jd.id/zhipu/amZzL3Q5MS8yMjgvMTEz...            0
# 1     https://img12.jd.id/zhipu/amZzL3Q5Ny8yNy8xMTEy...            0
# 2     https://img12.jd.id/zhipu/amZzL3Q5Ny8yMDgvNjI2...            0
# 3     https://img12.jd.id/zhipu/amZzL3QxMDAvMTE1Lzc1...            0
# 4     https://img12.jd.id/zhipu/amZzL3Q4OC84Ni83MDgx...            0
# ...                                                 ...          ...
# 1118  https://img12.jd.id/zhipu/amZzL3QzNC8xNy81NDEw...            0
# ...

# %%
df_review = pd.json_normalize(data_product[2]['review_detail'])
df_review
# Out:
#    userNickName                                          userImage country  \
# 0        w****6                                               None    None
# 1        h****i                                               None    None
# 2        w****a                                               None    None
# 3        S****8                                               None    None
# 4        S****a                    nHBfsgAAWgAAABQAHfApSQAAG4Q.jpg    None
# 5        n****7  amZzL3QxMDkvMjY0LzQxOTMwMzQzLzgzNDAvZjdiODUzNT...    None
# 6        a****a  amZzL3Q3Ni8yNTcvNTU4MTI2NDQ4Lzg5NDQvYjBjNGYxZj...    None
# 7        M****w                                               None    None
# 8        j****Q                                               None    None
# 9        j****a                                               None    None
# 10       j****A                                               None    None
# ...
